# %% [markdown]
# <a href="https://colab.research.google.com/github/bobi404/Scientific-Computing-LAB/blob/main/SC_Sesi5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

h = 0.1
x = np.arange(0, 2*np.pi, h)
y = np.cos(x)

forward_diff = np.diff(y)/h
x_diff = x[:-1]

exact_solution = -np.sin(x_diff)

plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', label='Finite difference approx')
plt.plot(x_diff, exact_solution, label='Exact solution')
plt.legend()
plt.show()

max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.049984407218554114

# %%
# rimann

import numpy as np
def f(x):
  return 4*x**4 + 2*x**3 - 6*x

#left rigmann
a = -3
b = 3
n = 30

lebar = (b-a)/(n-1)
x = np.linspace(a, b, n)
y = f(x)

left_rigmann = lebar*sum(y[:n-1])
print(left_rigmann)
# Out:
# 384.4323034267851

# %%
#mid_ridmann

a = -3
b = 3
n = 30

lebar = (b-a)/(n-1)
x_mid = (x[:n-1] + x[1:])/2
y_mid = f(x_mid)

mid_rigmann = lebar*sum(y_mid)
print(mid_rigmann)

#trapezoid

a = -3
b = 3
n = 30

lebar = (b-a)/(n-1)
x_mid = (x[:n-1] + x[1:])/2
y_mid = f(x_mid)

trapezoid = lebar*(y[0] + y[n-1] + 2*sum(y[1:n-1]))/2
print(trapezoid)
# Out:
# 387.26026006636687
# 391.88057928885405

# %%
#simsons rule

a = 0
b = np.pi
n = 10
h = (b-a)/n
x = np.linspace(a, b, n+1)
y = np.sin(x)

s = h/3*(y[0] + y[-1] + 4*sum(y[1:-1:2])  + 2*sum(y[2:n:2]))
exact = 2
error = abs(exact - s)
print(s, error)
# Out:
# 2.0001095173150043 0.00010951731500430384

# %% [markdown]
# Diff

# %%
x = [0, 0.1, 0.2, 0.3, 0.4]
y = [0, 0.0819, 0.1341, 0.1646, 0.1797]
h = 0.1

dy_dx_0 = (y[1] - y[0]) / h
dy_dx_02 = (y[3] - y[1]) / (2 * h)

print(f"Turunan pertama di x=0: {dy_dx_0:.4f}")
print(f"Turunan pertama di x=0.2: {dy_dx_02:.4f}")
# Out:
# Turunan pertama di x=0: 0.8190
# Turunan pertama di x=0.2: 0.4135

# %% [markdown]
# Integral

# %%
import math
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    result = 0.5 * (f(a) + f(b))
    for i in range(1, n):
        result += f(a + i * h)
    return result * h

f = math.sin
a = 0
b = math.pi

integral_8 = trapezoidal_rule(f, a, b, 8)
integral_16 = trapezoidal_rule(f, a, b, 16)

print(f"Integral dengan 8 panel: {integral_8:.6f}")
print(f"Integral dengan 16 panel: {integral_16:.6f}")
# Out:
# Integral dengan 8 panel: 1.974232
# Integral dengan 16 panel: 1.993570
